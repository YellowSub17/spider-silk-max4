# %%
# %load_ext autoreload
# %autoreload 2
from src.scan import Scan
from src.combo_scan import ComboScan
from src.det import pilatus_det, eiger_det
from src import const
import matplotlib.pyplot as plt
import numpy as np
import pandas
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pandas.read_csv(f'{const.DATA_PATH}/scans_clean.csv')

# %%
scan_ids_cap1_1 =df[df["Sample"] == f"cap2"]["scanID"].tolist()[:6]
print(scan_ids_cap1_1)
cs_p_cap1_1 = ComboScan(scan_ids=scan_ids_cap1_1, det=pilatus_det)
cs_p_cap1_1.plot_iqs()

scan_ids_cap1_2 =df[df["Sample"] == f"cap2"]["scanID"].tolist()[6:]
print(scan_ids_cap1_2)
cs_p_cap1_2 = ComboScan(scan_ids=scan_ids_cap1_2, det=pilatus_det)
cs_p_cap1_2.plot_iqs()
# Out:
# [102821, 102822, 102823, 102824, 102825, 102826]
# Loading Scans for ComboScan:	6/6
# Done.
# [102827, 102828, 102829, 102830, 102831, 102832]
# Loading Scans for ComboScan:	6/6
# Done.

# %%
scan_ids_cap2_1 =df[df["Sample"] == f"cap2"]["scanID"].tolist()[:6]
print(scan_ids_cap2_1)
cs_p_cap2_1 = ComboScan(scan_ids=scan_ids_cap2_1, det=eiger_det)
cs_p_cap2_1.plot_iqs(logX=False)

scan_ids_cap2_2 =df[df["Sample"] == f"cap2"]["scanID"].tolist()[6:]
print(scan_ids_cap2_2)
cs_p_cap2_2 = ComboScan(scan_ids=scan_ids_cap2_2, det=eiger_det)
cs_p_cap2_2.plot_iqs(logX=False)
# Out:
# [102832, 102831, 102830, 102829, 102828, 102827]
# Loading Scans for ComboScan:	6/6
# Done.
# [102826, 102825, 102824, 102823, 102822, 102821]
# Loading Scans for ComboScan:	6/6
# Done.

# %%
scan_ids_cap3 =df[df["Sample"] == f"cap3"]["scanID"].tolist()[:6]
print(scan_ids_cap3)
cs_p_cap1_1 = ComboScan(scan_ids=scan_ids_cap3, det=eiger_det)
cs_p_cap1_1.plot_iqs(logX=False)
# Out:
# [102851, 102850, 102849, 102848, 102847, 102846]
# Loading Scans for ComboScan:	6/6
# Done.
