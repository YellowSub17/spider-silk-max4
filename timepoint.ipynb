# %%
# %load_ext autoreload
# %autoreload 2
import src
import matplotlib.pyplot as plt


scan_ids = [i for i in range(102688, 102705)]

#tp1 = src.ComboScan(scan_ids = scan_ids[::3], det='eiger')

tp2 = src.ComboScan(scan_ids = scan_ids[1::3], det='eiger')

#tp3 = src.ComboScan(scan_ids = scan_ids[2::3], det='eiger')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 5/6

# %%
#tp1.plot_iq(logI=True, logq=True)
tp2.plot_iq(logI=True, logq=True)
#tp3.plot_iq(logI=True, logq=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #tp1.plot_iq(logI=True, logq=True)
# ----> 2 tp2.plot_iq(logI=True, logq=True)
#       3 #tp3.plot_iq(logI=True, logq=True)
#
# File ~/jupyter_notebooks/spider-silk-max4/src/scan_plot.py:11, in ScanPlot.plot_iq(self, logI, logq, errs)
#       9 def plot_iq(self, logI=False, logq=False, errs=False):
#      10     ## todo: add option to plot either or both the detectors
# ---> 11     self._plot(self.qs, self.Is)
#
# File ~/jupyter_notebooks/spider-silk-max4/src/scan_plot.py:53, in ScanPlot._plot(self, xs, ys, yerrs, new_fig, logX, logY, cmap)
#      51 cmap = plt.cm.get_cmap('viridis', ys.shape[0])
#      52 for i, (x, y, yerr) in enumerate(zip(xs, ys, yerrs)):
# ---> 53     plt.errorbar(x, ys[i,:], yerr=yerr[i,:], color=cmap(i))
#      57 plt.xlabel('q [1/A]')
#      58 plt.ylabel('Inten.')
#
# ...
