# %%
# %load_ext autoreload
# %autoreload 2
from src import Scan
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src import ComboScan
import matplotlib.pyplot as plt



cmb = ComboScan([i for i in range(102582, 102627)], det='pilatus')
cmb.plot_iq_errs()
# Out:
# 44/45

# %%
scan_id = 102584

scan=Scan(scan_id, det='pilatus')
scan.plot_iq_errs()
plt.title(scan.scan_id)
scan=Scan(scan_id, det='eiger')
scan.plot_iq(logq=True, logI=True)
plt.title(scan.scan_id)
scan.plot_img(i=1, log=True)

# %%
# %load_ext autoreload
# %autoreload 2
from src import Scan


for scan_id in range(102539, 102551):
    scan = Scan(scan_id=scan_id, det='pilatus')
    #scan.plot_img(i=None, log=True, )#xlim=[-0.01, 0.3], ylim=[-0.1,0] )
    #plt.title(scan_id)
    scan.plot_iq(log=True)
    plt.title(scan_id)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
