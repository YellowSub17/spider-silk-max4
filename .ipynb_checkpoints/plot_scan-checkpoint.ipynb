# %%
# %load_ext autoreload
# %autoreload 2
import utils
import matplotlib.pyplot as plt
s= utils.Scan(102452)

s.plot_iq()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !groups
# Out:
# Visitors sftp-access 20251747-group
