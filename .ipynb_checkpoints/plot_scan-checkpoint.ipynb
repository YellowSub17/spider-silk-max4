# %%
# %load_ext autoreload
# %autoreload 2
import utils
import matplotlib.pyplot as plt



s = utils.Scan(102470)
s.plot_pilatus_img(i=0)
print(s.pilatus_center)
print(utils.PILATUS_SHAPE)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (0.1763777868067733, 0.1929054147362801)
# [1475, 1679]
