# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import src
import pandas
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pandas.read_csv(f'{src.const.DATA_PATH}/scans_clean.csv')
for sample in df['Sample'].unique():
    print(sample)
# Out:
# nan
# Y2F+kpi/kpi
# Y2F+kpi/aa
# kpi/aa
# cap:YRA/kpi/no-shear
# cap:YRA/kpi/shear
# cap:YF/kpi/no-shear
# cap:YF/kpi/shear
# cap:WT/kpi/no-shear
# cap:WT/kpi/shear
# cap:YRA/h2o
# cap:YF/h2o
# cap:WT/h2o
# cap:kpi
# cap:kpi/aca
# cap:YF/kpi/gel
# cap:empty
# cap:YF/kpi/aa
# h2o/h2o
# Y2F+h2o/h2o
# Y2F+h2o/kpi
# kpi/h2o
# YR2A+h2o/kpi
# YR2A+h2o/h2o
# Y2F+kpi/h2o
# resin

# %%
scan_ids_1 = df[df["Sample"] == f"cap:WT/h2o"]["scanID"].tolist()
scan_ids_2 = df[df["Sample"] == f"cap:WT/kpi/no-shear"]["scanID"].tolist()
print(scan_ids_1)
# Out:
# [102823, 102829]

# %%
scans1 = src.ComboScan(scan_ids=scan_ids_1)
scans2 = src.ComboScan(scan_ids=scan_ids_2)
# Out:
# Loading Scans for ComboScan:	2/2
# Done.
# Loading Scans for ComboScan:	2/2
# Done.

# %%
scans1.plot_iq(cmap='jet')
scans2.plot_iq()

# %%
scans = src.ComboScan(scan_ids=[102811,102812, 102822,102826, 102828,102835,102828])
# Out:
# Loading Scans for ComboScan:	7/7
# Done.

# %%
scans.plot_iq()

# %%
scans = src.ComboScan([i for i in range(103609, 103623)])
# Out:
# Loading Scans for ComboScan:	14/14
# Done.

# %%
scans.plot_saxs()
print(scans.r_squared)
fig, axes = plt.subplots(1,1)
for i, r_sq in enumerate(scans.r_squared):
    if r_sq>0.999:
        scans.plot_iq(i=i, axes=axes)
# Out:
# [0.99989551 0.99990745 0.99985632 0.93521279 0.95433143 0.9999397
#  0.99170477 0.9912529  0.99992443 0.99769461 0.99985806 0.99987878
#  0.99988546 0.99988665]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import src
import pandas
from scipy import stats


for i in range(103115, 103115+14):
    scan = src.Scan(i, load_n=2)
    
   
    scan.plot_iq()
    plt.title(f'{i}, {scan.r_squared}, {scan.r_squared>0.999}')
    plt.vlines(src.det.LINEAR_SAXS_RANGE, ymin=1, ymax=1e3)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
