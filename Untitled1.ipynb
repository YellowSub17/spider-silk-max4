# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas
import matplotlib.pyplot as plt
from src.scan import Scan
from src import det
from src import const

# %%
s = Scan(102821)

# %%
plt.figure()
plt.plot(s.qs, s.Is[0], color='black')
plt.plot(s.qs_saxs, s.Is_saxs[0], linestyle='', color='red')
plt.plot(s.qs_waxs, s.Is_waxs[0]*s.saxswaxs_sf[0], linestyle='dashed')

plt.xscale('log')
plt.yscale('log')
plt.xlim(det.FULL_QRANGE)
# Out:
# (0.0031, 2.125)
